# %%
import requests
import pandas as pd
from scrapy import Selector
import time

# Liste des villes
villes = [
    "Mont Saint Michel", "St Malo", "Bayeux", "Le Havre", "Rouen",
    "Paris", "Amiens", "Lille", "Strasbourg", "Chateau du Haut Koenigsbourg",
    "Colmar", "Eguisheim", "Besancon", "Dijon", "Annecy", "Grenoble",
    "Lyon", "Gorges du Verdon", "Bormes les Mimosas", "Cassis",
    "Marseille", "Aix en Provence", "Avignon", "Uzes", "Nimes",
    "Aigues Mortes", "Saintes Maries de la mer", "Collioure",
    "Carcassonne", "Ariege", "Toulouse", "Montauban", "Biarritz",
    "Bayonne", "La Rochelle"
]

# %%
#parametre de recheche

type_logement = "ht_id=204"  # ht_id=204 pour les hôtels
date_debut = "2025-12-13"
date_fin = "2025-12-14"
n_adultes = 2
n_enfants = 0

# %%
url_base = "https://www.booking.com/searchresults.fr.html"

headers = {'User-agent' : 'Chrome/140.0.0.0',
           'accept-language': 'fr-FR,fr;q=0.9',
           'accept' : 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
           'cookie' : 'pcm_personalization_disabled=0; cors_js=1; OptanonAlertBoxClosed=2025-08-05T12:52:28.615Z; g_state={"i_l":0,"i_ll":1764672353073}; bkng_sso_session=eyJib29raW5nX2dsb2JhbCI6W3sibG9naW5faGludCI6IlBEQXlBUDJCbUJtQWFUOWllMzlLek5KQnY2TUdna2ZMbEgxNkFXMkhnUXMifV19; bkng_sso_ses=eyJib29raW5nX2dsb2JhbCI6W3siaCI6IlBEQXlBUDJCbUJtQWFUOWllMzlLek5KQnY2TUdna2ZMbEgxNkFXMkhnUXMifV19; pcm_consent=consentedAt%3D2025-12-02T10%3A45%3A59.377Z%26countryCode%3DFR%26expiresAt%3D2026-05-31T10%3A45%3A59.377Z%26implicit%3Dfalse%26regionCode%3DBRE%26regulation%3Dgdpr%26legacyRegulation%3Dgdpr%26consentId%3Df30da144-abb2-46b5-a33f-6bb73a1f882a%26analytical%3Dfalse%26marketing%3Dfalse; OptanonConsent=implicitConsentCountry=GDPR&implicitConsentDate=1754398319723&isGpcEnabled=0&datestamp=Tue+Dec+02+2025+16%3A28%3A40+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202501.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=0f4f89a6-5c41-4a19-992f-089a32d4f289&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false&backfilled_at=1754398349025&backfilled_seed=1&geolocation=FR%3BBRE; aws-waf-token=61e599e1-41e7-4544-ac74-966018edf308:DAoAe0Z6EkbnBAAA:; bkng_sso_auth=CAIQm8CWywYaigF+x4Ua8jS74AhGlWiVZrqmvzkCn92hdEmpAoLiiK+FdJsGZ7JoYpumtnosjJzDmLbuIRFtiPAGIzi89Ri3tWHpFRodUplbX847tnhWIyx+KiJ5pbnl5tPuBD2yinCQGdZmKXaxcL2Rd3TbnVP39ugahzU8tTuZNsMt+MaQd0Y6X8MSzw2DuvX79Dk=; BJS=-; bkng=11UmFuZG9tSVYkc2RlIyh9Yaa29%2F3xUOLbmlZgMctCRAYKxCXj3gOHipOqTl5bZuZbANaU%2FaxVLuQXsvoXxoTFxfbr8P78m%2Fr7ZTIYSzR6Fd7tP15WRzPrECSLFl4PNySD4Ybnpc%2FvMAbGtHql5rSwj9TxAW7ayrNTQa02AkALr0NuGloqG%2BCvkfXlHHDdEMgaGvBVZiiUJH%2B186SWPaU576acWEFh%2FvOT8K%2F38hry8jfPPw66beQkF3Z8JCi6fqk4; OptanonConsent=implicitConsentCountry=GDPR&implicitConsentDate=1754398319723&isGpcEnabled=0&datestamp=Fri+Dec+05+2025+18%3A36%3A51+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=202501.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=0f4f89a6-5c41-4a19-992f-089a32d4f289&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A0%2CC0004%3A0&AwaitingReconsent=false&backfilled_at=1754398349025&backfilled_seed=1&geolocation=FR%3BBRE; pcm_pac=%5B%22457cbba2e13a0556679461f492cf34995ddd4d0c981c09ad685d61baf711b8ae%22%2C6%5D'

           }

# %%
# Liste pour stocker tous les DataFrames
all_dfs = []

for ville in villes:
    print(f"Scraping {ville}...")
    
    params = {"ss" : ville,
          "nflt": type_logement,
          "checkin" : date_debut,
          "checkout" : date_fin,
          "group_adultes":2,
          "group_children" :0}
    response = requests.get(url=url_base, headers=headers, params=params)
    
    if response.status_code != 200:
        print(f"  ⚠ Erreur {response.status_code} pour {ville}")
        continue
    
    selector = Selector(text=response.text)
    hotels = selector.css("div[class='aa97d6032f']")
    
    # Les selectors
    name_hotels = hotels.css("div[class='b87c397a13 a3e0b4ffd1']::text").getall()
    notes_hotels = hotels.css("div[class='f63b14ab7a dff2e52086']::text").getall()
    web_hotels = hotels.css('a[data-testid="title-link"]::attr(href)').getall()
    experience_hotels = hotels.css("div[class='fff1944c52 fb14de7f14 eaa8455879']::text").getall()
    descri_hotels = hotels.css("h4[class='fff1944c52 f254df5361']::text").getall()
     
    # Création de la map du DataFrame pour cette ville
    n = len(name_hotels)
    df_ville = pd.DataFrame({
        "ville": [ville] * n,
        "nom": name_hotels,
        "note": notes_hotels[:n],  # Ajuster la longueur si nécessaire
        "site_web": web_hotels[:n],
        "nb_experience": experience_hotels[:n],
        "description": descri_hotels[:n],
    })
    
    all_dfs.append(df_ville)
    print(f"  ✓ {len(df_ville)} hôtels trouvés")
    
    # Pause pour éviter le blocage
    time.sleep(2)

# Concaténer tous les DataFrames
df_final = pd.concat(all_dfs, ignore_index=True)
df_final.index = df_final.index + 1

# Trier par note
df_final["note"] = pd.to_numeric(df_final["note"].str.replace(",", "."), errors="coerce")
df_final = df_final.sort_values(by="note", ascending=False)

# Sauvegarder
df_final.to_csv("booking_hotels_france.csv", index=True)
print(f"\n✓ Total : {len(df_final)} hôtels sauvegardés")
# Out:
# Scraping Mont Saint Michel...
#   ✓ 25 hôtels trouvés
# Scraping St Malo...
#   ✓ 25 hôtels trouvés
# Scraping Bayeux...
#   ✓ 25 hôtels trouvés
# Scraping Le Havre...
#   ✓ 25 hôtels trouvés
# Scraping Rouen...
#   ✓ 25 hôtels trouvés
# Scraping Paris...
#   ✓ 26 hôtels trouvés
# Scraping Amiens...
#   ✓ 24 hôtels trouvés
# Scraping Lille...
#   ✓ 25 hôtels trouvés
# Scraping Strasbourg...
#   ✓ 25 hôtels trouvés
# Scraping Chateau du Haut Koenigsbourg...
#   ✓ 13 hôtels trouvés
# Scraping Colmar...
#   ✓ 9 hôtels trouvés
# Scraping Eguisheim...
#   ✓ 10 hôtels trouvés
# Scraping Besancon...
#   ✓ 25 hôtels trouvés
# Scraping Dijon...
#   ✓ 25 hôtels trouvés
# Scraping Annecy...
#   ✓ 25 hôtels trouvés
# Scraping Grenoble...
#   ✓ 25 hôtels trouvés
# Scraping Lyon...
#   ✓ 25 hôtels trouvés
# Scraping Gorges du Verdon...
#   ✓ 8 hôtels trouvés
# Scraping Bormes les Mimosas...
#   ✓ 25 hôtels trouvés
# Scraping Cassis...
#   ✓ 25 hôtels trouvés
# Scraping Marseille...
#   ✓ 25 hôtels trouvés
# Scraping Aix en Provence...
#   ✓ 26 hôtels trouvés
# Scraping Avignon...
#   ✓ 25 hôtels trouvés
# Scraping Uzes...
#   ✓ 25 hôtels trouvés
# Scraping Nimes...
#   ✓ 25 hôtels trouvés
# Scraping Aigues Mortes...
#   ✓ 25 hôtels trouvés
# Scraping Saintes Maries de la mer...
#   ✓ 25 hôtels trouvés
# Scraping Collioure...
#   ✓ 25 hôtels trouvés
# Scraping Carcassonne...
#   ✓ 25 hôtels trouvés
# Scraping Ariege...
#   ✓ 25 hôtels trouvés
# Scraping Toulouse...
#   ✓ 25 hôtels trouvés
# Scraping Montauban...
#   ✓ 25 hôtels trouvés
# Scraping Biarritz...
#   ✓ 25 hôtels trouvés
# Scraping Bayonne...
#   ✓ 25 hôtels trouvés
# Scraping La Rochelle...
#   ✓ 25 hôtels trouvés
#
# ✓ Total : 816 hôtels sauvegardés

# %%
df_final.describe()
# Out:
#              note
# count  816.000000
# mean     8.140686
# std      0.646415
# min      5.300000
# 25%      7.800000
# 50%      8.200000
# 75%      8.600000
# max     10.000000
